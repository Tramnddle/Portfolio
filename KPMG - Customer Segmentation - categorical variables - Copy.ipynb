# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'D:\KPMG virtual internship data analytics\Sprocket_customer_segment.csv', encoding="ISO-8859-1")

# %%
df
# Out:
#       customer_id      first_name  last_name  gender  \
# 0             1.0         Laraine  Medendorp       F
# 1             2.0             Eli    Bockman    Male
# 2             3.0           Arlin     Dearle    Male
# 3             4.0          Talbot        NaN    Male
# 4             5.0  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3996       3997.0          Blanch     Nisuis  Female
# 3997       3998.0          Sarene    Woolley       U
# 3998       3999.0       Patrizius        NaN    Male
# 3999       4000.0           Kippy    Oldland    Male
# 4000          NaN             NaN        NaN     NaN
#
#       past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                    93.0  1953-10-12     Executive Secretary
# 1                                    81.0  1980-12-16  Administrative Officer
# 2                                    61.0  1954-01-20      Recruiting Manager
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Columns: 256 entries, customer_id to Unnamed: 255
# dtypes: float64(246), object(10)
# memory usage: 7.8+ MB

# %%
df.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure  \
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000
#
#               Sales  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# count   4000.000000          0.0          0.0          0.0          0.0
# mean    5488.169193          NaN          NaN          NaN          NaN
# std     3454.728755          NaN          NaN          NaN          NaN
# ...

# %%
df= df.drop(df.columns[13:], axis=1)
df
# Out:
#       customer_id      first_name  last_name  gender  \
# 0             1.0         Laraine  Medendorp       F
# 1             2.0             Eli    Bockman    Male
# 2             3.0           Arlin     Dearle    Male
# 3             4.0          Talbot        NaN    Male
# 4             5.0  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3996       3997.0          Blanch     Nisuis  Female
# 3997       3998.0          Sarene    Woolley       U
# 3998       3999.0       Patrizius        NaN    Male
# 3999       4000.0           Kippy    Oldland    Male
# 4000          NaN             NaN        NaN     NaN
#
#       past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                    93.0  1953-10-12     Executive Secretary
# 1                                    81.0  1980-12-16  Administrative Officer
# 2                                    61.0  1954-01-20      Recruiting Manager
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
x= [3,7,8,11]
def drop_na(x,df):
    li=[]
    for i in x:
        li.append(df.columns[i])
    return df.dropna(subset=li)

# %%
drop_na(x,df)
# Out:
#       customer_id first_name  last_name  gender  \
# 0             1.0    Laraine  Medendorp       F
# 1             2.0        Eli    Bockman    Male
# 2             3.0      Arlin     Dearle    Male
# 3             4.0     Talbot        NaN    Male
# 5             6.0       Curr  Duckhouse    Male
# ...           ...        ...        ...     ...
# 3994       3995.0      Rusty     Iapico    Male
# 3995       3996.0    Rosalia   Halgarth  Female
# 3996       3997.0     Blanch     Nisuis  Female
# 3997       3998.0     Sarene    Woolley       U
# 3998       3999.0  Patrizius        NaN    Male
#
#       past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                    93.0  1953-10-12     Executive Secretary
# 1                                    81.0  1980-12-16  Administrative Officer
# 2                                    61.0  1954-01-20      Recruiting Manager
# ...

# %%
df.dropna(subset=['gender', 'job_industry_category', 'wealth_segment', 'owns_car'])
# Out:
#       customer_id first_name  last_name  gender  \
# 0             1.0    Laraine  Medendorp       F
# 1             2.0        Eli    Bockman    Male
# 2             3.0      Arlin     Dearle    Male
# 3             4.0     Talbot        NaN    Male
# 5             6.0       Curr  Duckhouse    Male
# ...           ...        ...        ...     ...
# 3994       3995.0      Rusty     Iapico    Male
# 3995       3996.0    Rosalia   Halgarth  Female
# 3996       3997.0     Blanch     Nisuis  Female
# 3997       3998.0     Sarene    Woolley       U
# 3998       3999.0  Patrizius        NaN    Male
#
#       past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                    93.0  1953-10-12     Executive Secretary
# 1                                    81.0  1980-12-16  Administrative Officer
# 2                                    61.0  1954-01-20      Recruiting Manager
# ...

# %%
job_industry_dummies=pd.get_dummies(df['job_industry_category'],drop_first=True)
job_industry_dummies
# Out:
#       Entertainment  Financial Services  Health  IT  Manufacturing  Property  \
# 0                 0                   0       1   0              0         0
# 1                 0                   1       0   0              0         0
# 2                 0                   0       0   0              0         1
# 3                 0                   0       0   1              0         0
# 4                 0                   0       0   0              0         0
# ...             ...                 ...     ...  ..            ...       ...
# 3996              0                   0       0   0              1         0
# 3997              0                   0       0   1              0         0
# 3998              0                   0       0   0              1         0
# 3999              0                   0       0   0              0         0
# 4000              0                   0       0   0              0         0
#
#       Retail  Telecommunications
# ...

# %%
One=job_industry_dummies.iloc[:,0]
Two=job_industry_dummies.iloc[:,1]
Three=job_industry_dummies.iloc[:,2]
Four=job_industry_dummies.iloc[:,3]
Five=job_industry_dummies.iloc[:,4]
Six=job_industry_dummies.iloc[:,5]
Seven=job_industry_dummies.iloc[:,6]
Eight=job_industry_dummies.iloc[:,7]

# %%
def dummies():
    i=0
    for i in range(len(job_industry_dummies)):
        new_dummies=job_industry_dummies.iloc[:,i]
        return pd.concat([df, new_dummies], axis=1)
        i+=1

# %%
dummies()
# Out:
#       customer_id      first_name  last_name  gender  \
# 0             1.0         Laraine  Medendorp       F
# 1             2.0             Eli    Bockman    Male
# 2             3.0           Arlin     Dearle    Male
# 3             4.0          Talbot        NaN    Male
# 4             5.0  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3996       3997.0          Blanch     Nisuis  Female
# 3997       3998.0          Sarene    Woolley       U
# 3998       3999.0       Patrizius        NaN    Male
# 3999       4000.0           Kippy    Oldland    Male
# 4000          NaN             NaN        NaN     NaN
#
#       past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                    93.0  1953-10-12     Executive Secretary
# 1                                    81.0  1980-12-16  Administrative Officer
# 2                                    61.0  1954-01-20      Recruiting Manager
# ...

# %%
pd.concat([df,One, Two, Three, Four, Five, Six, Seven, Eight], axis=1)
# Out:
#       customer_id      first_name  last_name  gender  \
# 0             1.0         Laraine  Medendorp       F
# 1             2.0             Eli    Bockman    Male
# 2             3.0           Arlin     Dearle    Male
# 3             4.0          Talbot        NaN    Male
# 4             5.0  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3996       3997.0          Blanch     Nisuis  Female
# 3997       3998.0          Sarene    Woolley       U
# 3998       3999.0       Patrizius        NaN    Male
# 3999       4000.0           Kippy    Oldland    Male
# 4000          NaN             NaN        NaN     NaN
#
#       past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                    93.0  1953-10-12     Executive Secretary
# 1                                    81.0  1980-12-16  Administrative Officer
# 2                                    61.0  1954-01-20      Recruiting Manager
# ...
